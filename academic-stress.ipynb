# %%
import numpy as np

import pandas as pd

import plotly.express as px

import seaborn as sns

import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings('ignore')

cloud = pd.read_csv('/kaggle/input/student-stress-factors-a-comprehensive-analysis/StressLevelDataset.csv')

cloud
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
cloud.head().style.background_gradient('Greens')
# Out:
# <style type="text/css">
# #T_c7347_row0_col0, #T_c7347_row0_col3, #T_c7347_row0_col10, #T_c7347_row1_col8, #T_c7347_row1_col17, #T_c7347_row2_col1, #T_c7347_row2_col9, #T_c7347_row2_col10, #T_c7347_row2_col13, #T_c7347_row3_col9, #T_c7347_row3_col17, #T_c7347_row4_col8, #T_c7347_row4_col9, #T_c7347_row4_col13 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_c7347_row0_col1, #T_c7347_row0_col18 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# ...

# %%
cloud.tail().style.background_gradient('flare')
# Out:
# <style type="text/css">
# #T_c0e1a_row0_col0 {
#   background-color: #d44c60;
#   color: #f1f1f1;
# }
# #T_c0e1a_row0_col1 {
#   background-color: #9d3670;
#   color: #f1f1f1;
# }
# #T_c0e1a_row0_col2, #T_c0e1a_row0_col5, #T_c0e1a_row1_col2, #T_c0e1a_row1_col4, #T_c0e1a_row1_col6, #T_c0e1a_row1_col7, #T_c0e1a_row1_col8, #T_c0e1a_row1_col12, #T_c0e1a_row1_col13, #T_c0e1a_row1_col14, #T_c0e1a_row1_col15, #T_c0e1a_row1_col16, #T_c0e1a_row2_col0, #T_c0e1a_row2_col2, #T_c0e1a_row2_col3, #T_c0e1a_row2_col13, #T_c0e1a_row2_col15, #T_c0e1a_row2_col17, #T_c0e1a_row2_col19, #T_c0e1a_row2_col20, #T_c0e1a_row3_col1, #T_c0e1a_row3_col10, #T_c0e1a_row3_col11, #T_c0e1a_row3_col14, #T_c0e1a_row3_col16, #T_c0e1a_row4_col6, #T_c0e1a_row4_col9, #T_c0e1a_row4_col16, #T_c0e1a_row4_col18 {
#   background-color: #edb081;
#   color: #000000;
# }
# #T_c0e1a_row0_col3 {
#   background-color: #943470;
#   color: #f1f1f1;
# }
# #T_c0e1a_row0_col4, #T_c0e1a_row0_col6, #T_c0e1a_row4_col4, #T_c0e1a_row4_col12 {
# ...

# %% [markdown]
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
cloud.shape
# Out:
# (1100, 21)

# %%
cloud.columns
# Out:
# Index(['anxiety_level', 'self_esteem', 'mental_health_history', 'depression',
#        'headache', 'blood_pressure', 'sleep_quality', 'breathing_problem',
#        'noise_level', 'living_conditions', 'safety', 'basic_needs',
#        'academic_performance', 'study_load', 'teacher_student_relationship',
#        'future_career_concerns', 'social_support', 'peer_pressure',
#        'extracurricular_activities', 'bullying', 'stress_level'],
#       dtype='object')

# %%
cloud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %%
cloud.describe().style.background_gradient('Blues')
# Out:
# <style type="text/css">
# #T_9860b_row0_col0, #T_9860b_row0_col1, #T_9860b_row0_col2, #T_9860b_row0_col3, #T_9860b_row0_col4, #T_9860b_row0_col5, #T_9860b_row0_col6, #T_9860b_row0_col7, #T_9860b_row0_col8, #T_9860b_row0_col9, #T_9860b_row0_col10, #T_9860b_row0_col11, #T_9860b_row0_col12, #T_9860b_row0_col13, #T_9860b_row0_col14, #T_9860b_row0_col15, #T_9860b_row0_col16, #T_9860b_row0_col17, #T_9860b_row0_col18, #T_9860b_row0_col19, #T_9860b_row0_col20 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9860b_row1_col0, #T_9860b_row1_col3, #T_9860b_row2_col1, #T_9860b_row4_col1, #T_9860b_row5_col0, #T_9860b_row5_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_9860b_row1_col1, #T_9860b_row5_col1, #T_9860b_row6_col3, #T_9860b_row7_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# ...

# %%
def missing_data(cloud):
    
    return cloud.isnull().sum().sort_values(ascending=False).to_frame(name='Total').assign(
        
        Percentage=lambda x: (x / len(cloud) * 100)
    ).style.background_gradient(cmap='Greens')

missing_data(cloud)
# Out:
# <style type="text/css">
# #T_761c8_row0_col0, #T_761c8_row0_col1, #T_761c8_row1_col0, #T_761c8_row1_col1, #T_761c8_row2_col0, #T_761c8_row2_col1, #T_761c8_row3_col0, #T_761c8_row3_col1, #T_761c8_row4_col0, #T_761c8_row4_col1, #T_761c8_row5_col0, #T_761c8_row5_col1, #T_761c8_row6_col0, #T_761c8_row6_col1, #T_761c8_row7_col0, #T_761c8_row7_col1, #T_761c8_row8_col0, #T_761c8_row8_col1, #T_761c8_row9_col0, #T_761c8_row9_col1, #T_761c8_row10_col0, #T_761c8_row10_col1, #T_761c8_row11_col0, #T_761c8_row11_col1, #T_761c8_row12_col0, #T_761c8_row12_col1, #T_761c8_row13_col0, #T_761c8_row13_col1, #T_761c8_row14_col0, #T_761c8_row14_col1, #T_761c8_row15_col0, #T_761c8_row15_col1, #T_761c8_row16_col0, #T_761c8_row16_col1, #T_761c8_row17_col0, #T_761c8_row17_col1, #T_761c8_row18_col0, #T_761c8_row18_col1, #T_761c8_row19_col0, #T_761c8_row19_col1, #T_761c8_row20_col0, #T_761c8_row20_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_761c8">
#   <thead>
# ...

# %%
cloud.dtypes
# Out:
# anxiety_level                   int64
# self_esteem                     int64
# mental_health_history           int64
# depression                      int64
# headache                        int64
# blood_pressure                  int64
# sleep_quality                   int64
# breathing_problem               int64
# noise_level                     int64
# living_conditions               int64
# safety                          int64
# basic_needs                     int64
# academic_performance            int64
# study_load                      int64
# teacher_student_relationship    int64
# future_career_concerns          int64
# social_support                  int64
# peer_pressure                   int64
# extracurricular_activities      int64
# bullying                        int64
# stress_level                    int64
# dtype: object

# %%
plt.figure(figsize=(18,8))
sns.heatmap(cloud.corr(),annot=True,cmap='Blues')
plt.show()

# %%
q1 = np.percentile(cloud, 25)
q3 = np.percentile(cloud, 75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = (cloud < lower_bound) | (cloud > upper_bound)

outliers.describe()
# Out:
#        anxiety_level self_esteem mental_health_history depression headache  \
# count           1100        1100                  1100       1100     1100
# unique             2           2                     1          2        1
# top             True        True                 False       True    False
# freq             711         879                  1100        732     1100
#
#        blood_pressure sleep_quality breathing_problem noise_level  \
# count            1100          1100              1100        1100
# unique              1             1                 1           1
# top             False         False             False       False
# freq             1100          1100              1100        1100
#
#        living_conditions  ... basic_needs academic_performance study_load  \
# count               1100  ...        1100                 1100       1100
# unique                 1  ...           1                    1          1
# ...

# %%
sns.boxplot(x='stress_level',y='anxiety_level',data=cloud,color='c') # q1,q2,q3 percentiles 25%,50%,75%, circles = outliers
# Out:
# <Axes: xlabel='stress_level', ylabel='anxiety_level'>

# %%
sns.boxplot(x='stress_level',y='self_esteem',data=cloud,color='m') # q1,q2,q3 percentiles 25%,50%,75%, circles = outliers
# Out:
# <Axes: xlabel='stress_level', ylabel='self_esteem'>

# %%
sns.boxplot(x='stress_level',y='depression',data=cloud,color='y') # q1,q2,q3 percentiles 25%,50%,75%, circles = outliers
# Out:
# <Axes: xlabel='stress_level', ylabel='depression'>

# %%
# q1 = np.percentile(cloud, 25)
# q3 = np.percentile(cloud, 75)
# iqr = q3 - q1
# lower_bound = q1 - 1.5 * iqr
# upper_bound = q3 + 1.5 * iqr

# gemini = cloud[(cloud >= lower_bound) & (cloud <= upper_bound)]

# gemini

# %%
from scipy.stats import zscore

z_scores = zscore(cloud)
outliers = (abs(z_scores) > 10)  # You can adjust the threshold as needed
gemini = cloud[~outliers]

gemini
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
def missing_data(gemini):
    
    return gemini.isnull().sum().sort_values(ascending=False).to_frame(name='Total').assign(
        
        Percentage=lambda x: (x / len(gemini) * 100)
    ).style.background_gradient(cmap='Greens')

missing_data(gemini)
# Out:
# <style type="text/css">
# #T_9890a_row0_col0, #T_9890a_row0_col1, #T_9890a_row1_col0, #T_9890a_row1_col1, #T_9890a_row2_col0, #T_9890a_row2_col1, #T_9890a_row3_col0, #T_9890a_row3_col1, #T_9890a_row4_col0, #T_9890a_row4_col1, #T_9890a_row5_col0, #T_9890a_row5_col1, #T_9890a_row6_col0, #T_9890a_row6_col1, #T_9890a_row7_col0, #T_9890a_row7_col1, #T_9890a_row8_col0, #T_9890a_row8_col1, #T_9890a_row9_col0, #T_9890a_row9_col1, #T_9890a_row10_col0, #T_9890a_row10_col1, #T_9890a_row11_col0, #T_9890a_row11_col1, #T_9890a_row12_col0, #T_9890a_row12_col1, #T_9890a_row13_col0, #T_9890a_row13_col1, #T_9890a_row14_col0, #T_9890a_row14_col1, #T_9890a_row15_col0, #T_9890a_row15_col1, #T_9890a_row16_col0, #T_9890a_row16_col1, #T_9890a_row17_col0, #T_9890a_row17_col1, #T_9890a_row18_col0, #T_9890a_row18_col1, #T_9890a_row19_col0, #T_9890a_row19_col1, #T_9890a_row20_col0, #T_9890a_row20_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_9890a">
#   <thead>
# ...

# %%
x = cloud.iloc[:,cloud.columns != 'stress_level']


x
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
y = cloud.iloc[:,-1]

y
# Out:
# 0       1
# 1       2
# 2       1
# 3       2
# 4       1
#        ..
# 1095    1
# 1096    2
# 1097    0
# 1098    2
# 1099    2
# Name: stress_level, Length: 1100, dtype: int64

# %%
cloud.columns
# Out:
# Index(['anxiety_level', 'self_esteem', 'mental_health_history', 'depression',
#        'headache', 'blood_pressure', 'sleep_quality', 'breathing_problem',
#        'noise_level', 'living_conditions', 'safety', 'basic_needs',
#        'academic_performance', 'study_load', 'teacher_student_relationship',
#        'future_career_concerns', 'social_support', 'peer_pressure',
#        'extracurricular_activities', 'bullying', 'stress_level'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y = train_test_split(x,y, test_size = 0.30, random_state = 42)

train_x
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 221              10           23                      1          13         2
# 235              16           13                      1          20         3
# 433               3           27                      0           8         1
# 599               7           25                      0           2         1
# 305               1           21                      0          11         3
# ...             ...          ...                    ...         ...       ...
# 466              18            6                      1          23         5
# 121              18            0                      1          18         5
# 1044             15            1                      1          23         3
# 1095             11           17                      0          14         3
# 860              10           15                      1          11         3
#
# ...

# %%
from sklearn.linear_model import LinearRegression

terrain= LinearRegression()

terrain.fit(train_x,train_y)

zephyr7b = terrain.predict(test_x)

zephyr7b
# Out:
# array([ 1.93325249e+00,  1.02507452e-02,  1.00802251e+00,  8.01654437e-01,
#         1.24260197e-01,  8.60942309e-01,  1.78416030e+00, -1.11374121e-01,
#         1.10412624e+00,  6.92379328e-01, -1.83044452e-01, -1.23756325e-01,
#         1.11369729e-01,  2.08797718e+00,  1.07639554e+00, -3.56013383e-02,
#         1.57043451e-03,  2.19428607e+00,  9.75931683e-01,  1.15625867e-01,
#         1.15661131e+00,  9.29540728e-01, -5.45128220e-02,  1.00965638e+00,
#         8.20773597e-01,  2.01250033e+00,  9.07460716e-01,  1.16307857e-01,
#         3.44859819e-04, -1.63555091e-02,  1.25544080e+00,  1.85973649e+00,
#         2.00255799e+00,  1.79714745e-02,  1.25842130e-02,  9.68939542e-01,
#         1.41267344e+00,  1.07214965e+00,  1.93267550e+00,  2.05655237e+00,
#         2.01351393e+00,  8.64055439e-02,  1.06543298e+00,  1.19070335e+00,
#         1.96092916e+00, -5.97412885e-02,  2.03091892e+00,  1.52213989e+00,
# ...

# %%
print(terrain.predict([[10,23,1,13,2,1,2,2,3,3,2,2,3,2,3,2,3,3,3,3]]))
# Out:
# [1.04919258]

# %%
print('Slope is :')

list(zip(x,terrain.coef_))
# Out:
# Slope is :
# [('anxiety_level', 0.0004749221711947196),
#  ('self_esteem', -0.01063843160933843),
#  ('mental_health_history', 0.020394701379904578),
#  ('depression', 0.0031166702041459534),
#  ('headache', 0.036408214954788735),
#  ('blood_pressure', -0.008327511484370808),
#  ('sleep_quality', -0.024281938947211115),
#  ('breathing_problem', 0.01712065907586773),
#  ('noise_level', 0.08170072320771676),
#  ('living_conditions', -0.008154185672529117),
#  ('safety', -0.04828373531772225),
#  ('basic_needs', -0.07800930452675262),
#  ('academic_performance', -0.04065903802280093),
#  ('study_load', 0.053770466177344926),
#  ('teacher_student_relationship', -0.0033711141919544655),
#  ('future_career_concerns', 0.014961073262965295),
#  ('social_support', -0.009067397174861372),
#  ('peer_pressure', -0.008130745407462454),
#  ('extracurricular_activities', 0.06611682235202376),
#  ('bullying', 0.08789699179040476)]

# %%
print('Constant is:' ,terrain.intercept_)
# Out:
# Constant is: 0.7941763412464639

# %%
dark = pd.DataFrame({'Actual_value':test_y,'Predicted_value': zephyr7b,'Difference': test_y- zephyr7b})

dark
# Out:
#       Actual_value  Predicted_value  Difference
# 328              2         1.933252    0.066748
# 688              0         0.010251   -0.010251
# 413              1         1.008023   -0.008023
# 788              1         0.801654    0.198346
# 244              0         0.124260   -0.124260
# ...            ...              ...         ...
# 1026             1         1.021485   -0.021485
# 254              0         0.139647   -0.139647
# 796              0         0.066143   -0.066143
# 312              0         0.876607   -0.876607
# 1065             2         0.758753    1.241247
#
# [330 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_percentage_error, r2_score

mape = mean_absolute_percentage_error(test_y, zephyr7b)

print('MAPE: {:.2%}'.format(mape))
# Out:
# MAPE: 36588303188475688.00%

# %%
print('R2 SCORE IS :', r2_score(test_y,zephyr7b))
# Out:
# R2 SCORE IS : 0.7892052608112265
